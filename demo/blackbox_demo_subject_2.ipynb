# %% [markdown]
# # Discriminative Visualization Demo - Subject 2

# %% [markdown]
# ## Evaluate Contrastive Saliency Using White Box as Black Box System (ResNet101)

# %% [markdown]
# ### Setup Dataset

# %%
ref = '../data/subject_2/ref-2.png'
probe = '../data/subject_2/probe-2.png'
gallery = '../data/subject_2/gallery-2.png'

# %% [markdown]
# ### Display Reference, Probe, and Non-Mate Gallery Images

# %%
from IPython.display import Image, display

display(Image(ref))
display(Image(probe))
display(Image(gallery))

# %% [markdown]
# ### Run Evaluation

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
np.random.seed(0)
import xfr.models.blackbox as bb

strise = bb.STRise(probe=probe,
                   refs=[ref],
                   gallery=[gallery],
                   black_box='resnetv6_pytorch')
strise.evaluate()
# Out:
# 1/5 Computing prior...
# 2/5 Generating masks...
# 3/5 Applying masks...
# 4/5 Scoring masks...
# 5/5 Computing saliency map...
# Finished!

# %% [markdown]
# ### Display Contrastive Saliency Map

# %%
import PIL.Image
from xfr.show import blend_saliency_map

overlay = blend_saliency_map(strise.probe/255.0, strise.saliency_map)
PIL.Image.fromarray(np.uint8(255*overlay))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4E91239A20>
